# %%
#Import libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Load the cleaned datasets
job_df.sample(1000, random_state=42).to_csv(
    "clean_job_small.csv",
    index=False
)

resume_df.sample(200, random_state=42).to_csv(
    "clean_resume_small.csv",
    index=False
)

print("Files created successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #Load the cleaned datasets
# ----> 2 job_df.sample(1000, random_state=42).to_csv(
#       3     "clean_jobs_small.csv",
#       4     index=False
#       5 )
#       7 resume_df.sample(200, random_state=42).to_csv(
#       8     "clean_resume_small.csv",
#       9     index=False
#      10 )
#      12 print("Files created successfully!")
#
# NameError: name 'job_df' is not defined

# %%
#Convert text into vectors
tfidf = TfidfVectorizer(max_features=5000)
job_vectors = tfidf.fit_transform(job_df["combined_text"])
resume_vectors = tfidf.transform(resume_df["combined_resume"])

# %%
#Check their shapes
print(job_vectors.shape)
print(resume_vectors.shape)
# Out:
# (22000, 5000)
# (2484, 5000)

# %%
# Apply cosine similarity
similarity = cosine_similarity(
    resume_vectors,
    job_vectors
)
print(similarity.shape)
# Out:
# (2484, 22000)

# %%
#Recommend jobs for the first resume
resume_index = 0
top_jobs = similarity[resume_index].argsort()[-5:][::-1]
recommendations = job_df.iloc[top_job]
print(
    recommendations[
        ["job_title", "organization", "location"]
    ]
)
# Out:
#                                                job_title  \
# 1461   Events & Public Relations Assistant Job in Orl...
# 10891  Public Relations & Communications Assistant - ...
# 10130                    Marketing Manager Job in Milton
# 8375        Marketing Manager- Entry Level Job in Aurora
# 8500   Public Relations Associate - Entry Level Job i...
#
#                                             organization             location
# 1461   RetailAdvertising and PR ServicesBusiness Serv...    Orlando, FL 32809
# 10891  Advertising and PR Services;Staffing/Employmen...  San Diego, CA 92123
# 10130     Construction - Residential & Commercial/Office     Milton, DE 19968
# 8375   Advertising and PR ServicesBusiness Services -...     Aurora, CO 80014
# 8500   Advertising and PR Services;Staffing/Employmen...  San Diego, CA 92123

# %%
print(similarity.shape)
# Out:
# (2484, 22000)

# %%
print(resume_df["combined_resume"][0])
# Out:
#          HR ADMINISTRATOR/MARKETING ASSOCIATE
#
# ...
